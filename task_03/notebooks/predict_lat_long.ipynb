# %%
import pandas as pd
import geopandas as gpd
from sqlalchemy import create_engine
import json
from datetime import datetime, timedelta
import folium
from shapely.geometry import Point, LineString, Polygon
from functools import partial
import pyproj
from shapely.ops import transform
import numpy as np
from shapely.ops import nearest_points
from pyproj import Geod
import warnings
import traceback
warnings.filterwarnings("ignore", message="invalid value encountered in line_locate_point")
geod = Geod(ellps="WGS84")

# %%
def load_df(path):
    with open(path, 'r') as file:
        data = json.load(file)

    df = pd.DataFrame(data)
    if 'datahora' in df.columns:
        df['datahora'] = pd.to_datetime(df['datahora'].astype(float), unit='ms') - pd.Timedelta(hours=3) # Ajuste para GMT-3]
    return df

# %%
def load_gdf_train(paths: tuple):
    gdf_train1 = load_df(paths[0])
    gdf_train2 = load_df(paths[1])

    gdf_train = pd.concat([gdf_train1, gdf_train2])
    gdf_train['latitude'] = gdf_train['latitude'].str.replace(',', '.').astype(float)
    gdf_train['longitude'] = gdf_train['longitude'].str.replace(',', '.').astype(float)
    geometry_points = [Point(xy) for xy in zip(gdf_train['longitude'], gdf_train['latitude'])]
    gdf_train = gpd.GeoDataFrame(gdf_train, crs='EPSG:4326', geometry=geometry_points)
    gdf_train = gdf_train.drop(['latitude', 'longitude', 'datahoraenvio', 'datahoraservidor'], axis=1)


    return gdf_train

# %%
database_uri = 'postgresql://postgres:admin@localhost:5432/gps_onibus_rj'
db_engine_alchemy = create_engine(database_uri)

# %%
def load_trajects_from_db(engine) -> gpd.GeoDataFrame:
    sql = """
    SELECT linha, conjunto_dia, 
        ST_AsText(ponto_inicial) as ponto_inicial_wkt, 
        ST_AsText(ponto_final) as ponto_final_wkt, 
        ST_AsText(trajeto) as trajeto_ida_wkt,
        ST_AsText(trajeto_volta) as trajeto_volta_wkt 
    FROM rotas 
    """
    df = pd.read_sql(sql, engine)

    df['ponto_inicial'] = gpd.GeoSeries.from_wkt(df['ponto_inicial_wkt'])
    df['ponto_final'] = gpd.GeoSeries.from_wkt(df['ponto_final_wkt'])
    df['trajeto_ida'] = gpd.GeoSeries.from_wkt(df['trajeto_ida_wkt'])
    df['trajeto_volta'] = gpd.GeoSeries.from_wkt(df['trajeto_volta_wkt'])

    df.drop(columns=['ponto_inicial_wkt', 'ponto_final_wkt', 'trajeto_ida_wkt', 'trajeto_volta_wkt'], inplace=True)

    gdf = gpd.GeoDataFrame(df, geometry='trajeto_ida', crs="EPSG:4326")

    gdf.set_geometry('ponto_inicial', inplace=True, crs="EPSG:4326")
    gdf.set_geometry('ponto_final', inplace=True, crs="EPSG:4326")
    gdf.set_geometry('trajeto_volta', inplace=True, crs="EPSG:4326")
    return gdf

# %%
def calculate_point_buffer(point:Point, radius_in_meters:int = 100):
    gdf = gpd.GeoDataFrame(geometry=[point], crs="EPSG:3857")
    point_buffer = gdf.geometry.buffer(radius_in_meters)
    return point_buffer[0]

# %%
# Function to project a point onto a LineString
def calculate_projection(row, trajectory_ida: LineString, trajectory_volta: LineString, inicio: Polygon, fim: Polygon):
    point: Point = row['current_position']
    # Use project method from Shapely to find projection
    if point.within(inicio):
        return Point(trajectory_ida.coords[0])
    if point.within(fim):
        return Point(trajectory_volta.coords[0])
    if row['direcao'] == 'ida':
        projection = trajectory_ida.interpolate(trajectory_ida.project(point))
    else:
        projection = trajectory_volta.interpolate(trajectory_volta.project(point))
    return projection

# %%
def filter_points_out_of_traject(gdf: gpd.GeoDataFrame, trajectory_ida:LineString, trajectory_volta:LineString) -> gpd.GeoDataFrame:
    gdf['buffer'] = gdf['current_position'].buffer(60)
    gdf_ida_meters = gpd.GeoDataFrame( geometry=[trajectory_ida], crs='EPSG:3857')
    gdf_volta_meters = gpd.GeoDataFrame( geometry=[trajectory_volta], crs='EPSG:3857')
    # Check if each buffer intersects with either trajectory_ida or trajectory_volta
    gdf['in_trajectory'] = gdf['buffer'].apply(lambda x: x.intersects(gdf_ida_meters.union_all()) or x.intersects(gdf_volta_meters.union_all()))
    gdf = gdf[gdf['in_trajectory'] == True]
    return gdf.drop(columns=['in_trajectory', 'buffer'])

# %%
def calculate_trajectory_direction_v2(row, trajectory_ida:LineString, trajectory_volta:LineString, inicio: Polygon, fim: Polygon):
    if pd.isnull(row['last_position']):
        return 'indefinido'
    
    p: Point = row['last_position']
    q: Point = row['current_position']
    if q.within(inicio):
        return 'ponto_inicial'
    if q.within(fim):
        return 'ponto_final'
    distance_in_meters = p.distance(q)
    if distance_in_meters < 10:
        return 'parado'
    
    project_p_in_ida = trajectory_ida.interpolate(trajectory_ida.project(p))
    project_q_in_ida = trajectory_ida.interpolate(trajectory_ida.project(q))
    distance_p_in_ida = trajectory_ida.project(project_p_in_ida)
    distance_q_in_ida = trajectory_ida.project(project_q_in_ida)

    project_p_in_volta = trajectory_volta.interpolate(trajectory_volta.project(p))
    project_q_in_volta = trajectory_volta.interpolate(trajectory_volta.project(q))
    distance_p_in_volta = trajectory_volta.project(project_p_in_volta)
    distance_q_in_volta = trajectory_volta.project(project_q_in_volta)

    distance_to_ida = p.distance(trajectory_ida) + q.distance(trajectory_ida)
    distance_to_volta = p.distance(trajectory_volta) + q.distance(trajectory_volta)
    
    if distance_q_in_ida > distance_p_in_ida and distance_to_ida < distance_to_volta:
        return 'ida'
    if distance_q_in_volta > distance_p_in_volta and distance_to_volta < distance_to_ida:
        return 'volta'

    return 'indefinido'

# %%
def change_dataframe_crs(gdf: gpd.GeoDataFrame, columns: list, crs):
    gdf_converted:gpd.GeoDataFrame = gdf.copy()
    for geom in columns:
        gdf_converted.set_geometry(geom, inplace=True)
        gdf_converted[geom] = gdf_converted.to_crs(epsg=crs)[geom]
    return gdf_converted

# %%
def calculate_average_speed(gdf: gpd.GeoDataFrame):
    filtered_gdf = gdf[gdf['velocidade'] <= 30]
    
    ida_speeds = filtered_gdf[filtered_gdf['direcao'] == 'ida']['velocidade']
    avg_ida = ida_speeds.mean() if not ida_speeds.empty else 10
    
    volta_speeds = filtered_gdf[filtered_gdf['direcao'] == 'volta']['velocidade']
    avg_volta = volta_speeds.mean() if not volta_speeds.empty else 10
    
    return {'ida': avg_ida, 'volta': avg_volta}

# %%
def calculate_average_time_on_stop(gdf: gpd.GeoDataFrame):

    time_spent_ponto_final = []
    time_spent_ponto_inicial = []
    for ordem in gdf['ordem'].unique():
        rows_ordem = gdf[gdf['ordem'] == ordem]
        rows_ordem = rows_ordem.sort_values(by=['datahora'])

        
        last_time = rows_ordem.iloc[0]['datahora']
        last_direction = None
        time_spent = 0

        # Iterate through rows
        for index, row in rows_ordem.iterrows():
            current_direction = row['direcao']
            if current_direction in ['ida', 'volta']:
                # Check if we have a previous "ponto_final" or "ponto_inicial"
                if last_direction == 'ponto_final':
                    time_spent_ponto_final.append(time_spent)
                elif last_direction == 'ponto_inicial':
                    time_spent_ponto_inicial.append(time_spent)
                time_spent = 0
            if current_direction in ['ponto_inicial', 'ponto_final']:
                time_spent += (row['datahora'] - last_time).total_seconds()
            last_time = row['datahora']
            last_direction = row['direcao']
            
    # Calculate average time difference for "ponto_final" and "ponto_inicial"
    average_time_ponto_final = sum(time_spent_ponto_final) / len(time_spent_ponto_final) if time_spent_ponto_final else 0
    average_time_ponto_inicial = sum(time_spent_ponto_inicial) / len(time_spent_ponto_inicial) if time_spent_ponto_inicial else 0
    return {'ponto_final': average_time_ponto_final, 'ponto_inicial': average_time_ponto_inicial}

# %%
def process_current_train_data(gdf_train: gpd.GeoDataFrame, df_trajectory: gpd.GeoDataFrame):
    # df_trajectory_3857 = change_dataframe_crs(df_trajectory, ['ponto_inicial', 'ponto_final', 'trajeto_ida', 'trajeto_volta'], 3857)
    df_trajectory_3857 = df_trajectory.copy()

    # gdf_train_3857 = change_dataframe_crs(gdf_train, ['geometry'], 3857)
    gdf_train_3857 = gdf_train.copy()
    
    trajectory_ida = df_trajectory_3857['trajeto_ida'].values[0]
    trajectory_volta = df_trajectory_3857['trajeto_volta'].values[0]
    ponto_inicial = df_trajectory_3857['ponto_inicial'].values[0]
    ponto_final = df_trajectory_3857['ponto_final'].values[0]
    inicio_buffer = calculate_point_buffer(ponto_inicial, 100)
    fim_buffer = calculate_point_buffer(ponto_final, 100)
    
    gdf_train_3857.rename(columns={'geometry':'current_position'}, inplace=True)
    gdf_train_3857 = filter_points_out_of_traject(gdf_train_3857, trajectory_ida, trajectory_volta)
    gdf_train_3857.sort_values(by=['ordem', 'datahora'], inplace=True)
    gdf_train_3857.reset_index()
    gdf_train_3857['last_position'] = gdf_train_3857['current_position'].shift(1)
    gdf_train_3857.loc[gdf_train_3857['ordem'] != gdf_train_3857['ordem'].shift(1), 'last_position'] = pd.NA # Se mudar de ordem, nao usar last_position
    gdf_train_3857.dropna(inplace=True, subset=['last_position'])

    gdf_train_3857['direcao'] = gdf_train_3857.apply(lambda x: calculate_trajectory_direction_v2(x, trajectory_ida, trajectory_volta, inicio_buffer, fim_buffer), axis=1)
    gdf_train_3857['direcao'] = gdf_train_3857['direcao'].replace({'parado': pd.NA, 'indefinido': pd.NA})
    gdf_train_3857['direcao'] = gdf_train_3857['direcao'].ffill()
    gdf_train_3857['direcao'] = gdf_train_3857['direcao'].bfill()
    
    # Create a new column for the projections
    gdf_train_3857['projected_point'] = gdf_train_3857.apply(lambda x: calculate_projection(x, trajectory_ida, trajectory_volta, inicio_buffer, fim_buffer), axis=1)
    gdf_train_3857.set_geometry('projected_point', inplace=True)
    gdf_train_3857.set_crs(epsg=3857, inplace=True)
    gdf_train_3857['last_projected_point'] = gdf_train_3857['projected_point'].shift(1)
    gdf_train_3857['distance_from_previous'] = gdf_train_3857.apply(lambda x: x['projected_point'].distance(x['last_projected_point']), axis=1)
    gdf_train_3857['last_datahora'] = gdf_train_3857['datahora'].shift(1)
    gdf_train_3857['time_from_previous'] = (gdf_train_3857['datahora'] - gdf_train_3857['last_datahora']).dt.total_seconds()
    
    
    # gdf_train_4326 = change_dataframe_crs(gdf_train_3857, ['current_position', 'last_position', 'projected_point'], 4326)
    # df_trajectory_4326 = change_dataframe_crs(df_trajectory_3857, ['ponto_inicial', 'ponto_final', 'trajeto_ida', 'trajeto_volta'], 4326)
    # trajectory_ida = df_trajectory_4326['trajeto_ida'].values[0]
    # trajectory_volta = df_trajectory_4326['trajeto_volta'].values[0]
    # ponto_inicial = df_trajectory_4326['ponto_inicial'].values[0]
    # ponto_final = df_trajectory_4326['ponto_final'].values[0]
    # gdf_train_4326['velocidade'] = gdf_train_4326['distance_from_previous'] / gdf_train_4326['time_from_previous']
    # gdf_train_4326['velocidade'] = pd.to_numeric(gdf_train_4326['velocidade'], errors='coerce')
    # gdf_train_4326.dropna(inplace=True, subset=['velocidade'])
    gdf_train_3857['velocidade'] = gdf_train_3857['distance_from_previous'] / gdf_train_3857['time_from_previous']
    gdf_train_3857['velocidade'] = pd.to_numeric(gdf_train_3857['velocidade'], errors='coerce')
    gdf_train_3857.dropna(inplace=True, subset=['velocidade'])
    
    return gdf_train_3857

# %%
def calculate_next_position_v2(last_position: Point, average_speed: float, trajectory: LineString, time_difference:float) -> Point:
    """
    Calculate the next position based on the last position, average speed, 
    trajectory (LineString), and time difference (in seconds).
    """
    distance_already_traveled = trajectory.project(last_position)
    distance_to_travel = (average_speed * time_difference) + distance_already_traveled
    
    if distance_to_travel >= trajectory.length:
        point_projected = trajectory.interpolate(trajectory.length)
        reached_end_of_route = True
    else:
        point_projected = trajectory.interpolate(distance_to_travel)
        reached_end_of_route = False

    return (point_projected, reached_end_of_route)

# %%
def predict_position_v2(gdf_train: gpd.GeoDataFrame, df_test: pd.DataFrame, tracjetories_df: gpd.GeoDataFrame):
    
    # gdf_train_3857 = change_dataframe_crs(gdf_train, ['current_position', 'last_position', 'projected_point', 'last_projected_point'], 3857)
    gdf_train_3857 = gdf_train.copy()

    # df_trajectory_3857 = change_dataframe_crs(tracjetories_df, ['ponto_inicial', 'ponto_final', 'trajeto_ida', 'trajeto_volta'], 3857)
    df_trajectory_3857 = tracjetories_df.copy()
    
    df_test = df_test.sort_values(by=['ordem', 'datahora'])
    
    trajectory_ida = df_trajectory_3857['trajeto_ida'].values[0]
    trajectory_volta = df_trajectory_3857['trajeto_volta'].values[0]
    
    def get_last_known_positions(gdf):
        last_positions = {}
        grouped = gdf.groupby('ordem')
        for name, group in grouped:
            last_position = group.iloc[-1]['projected_point']
            last_positions[name] = last_position
        return last_positions

    last_known_positions = get_last_known_positions(gdf_train_3857)
    df_test['geometry_predicted'] = None
    average_speed = calculate_average_speed(gdf_train_3857)
    average_time_on_stop_in_seconds = calculate_average_time_on_stop(gdf_train_3857)
    
    
    for ordem in df_test['ordem'].unique():
        ordem_rows = df_test[df_test['ordem'] == ordem]
        if ordem not in last_known_positions.keys():
            continue
        last_position = last_known_positions[ordem]
        last_time = gdf_train_3857[gdf_train_3857['ordem'] == ordem].iloc[-1]['datahora']
        last_direcao = gdf_train_3857[gdf_train_3857['ordem'] == ordem].iloc[-1]['direcao']
        
        time_spent_on_end = 0
        
        for idx, row in ordem_rows.iterrows():
            current_time = row['datahora']
            time_difference = (current_time - last_time).total_seconds()
            if last_direcao == 'ida':
                next_position, reached_final = calculate_next_position_v2(last_position, average_speed['ida'], trajectory_ida, time_difference)
                if reached_final:
                    last_direcao = 'ponto_final'

            elif last_direcao == 'volta':
                next_position, reached_final = calculate_next_position_v2(last_position, average_speed['volta'], trajectory_volta, time_difference)
                if reached_final:
                    last_direcao = 'ponto_inicial'

            elif last_direcao == 'ponto_inicial':
                time_spent_on_end += time_difference
                next_position = last_position
                if time_spent_on_end > average_time_on_stop_in_seconds['ponto_inicial']:
                    last_direcao = 'ida'
                    time_spent_on_end = 0
                next_position = last_position

            elif last_direcao == 'ponto_final':
                time_spent_on_end += time_difference
                if time_spent_on_end > average_time_on_stop_in_seconds['ponto_final']:
                    last_direcao = 'volta'
                    time_spent_on_end = 0
                next_position = last_position
                

            
            df_test.at[idx, 'geometry_predicted'] = next_position
            
            # Update the last position and last time for the next iteration
            last_position = next_position
            last_time = current_time
    
    df_test['geometry_predicted'] = gpd.GeoSeries(df_test['geometry_predicted'])
    gdf_test_3857 = gpd.GeoDataFrame(df_test, geometry='geometry_predicted', crs='EPSG:3857')
    gdf_test_3857 = gdf_test_3857.dropna(subset=['geometry_predicted'])
    # gdf_test_4326 = change_dataframe_crs(gdf_test_3857, columns=['geometry_predicted'], crs=4326)
    
    return gdf_test_3857

# %%
def execute_all_predictions(predictions_to_do: list):
    all_predictions = []
    trajectories_gdf = load_trajects_from_db(db_engine_alchemy)
    trajectories_gdf = change_dataframe_crs(trajectories_gdf, ['ponto_inicial', 'ponto_final', 'trajeto_ida', 'trajeto_volta'], 3857)
    
    for datahora, conjunto_dia in predictions_to_do:
        try:
            print(f"[{datetime.now().strftime('%H:%M:%S')}]Começando predição para {datahora}")
            predictions_for_this_datahora = []
            datahora_datetime = datetime.strptime(datahora, '%Y-%m-%d_%H')
            path_folder = f'data/predict/{datahora_datetime.strftime("%Y-%m-%d")}'

            print(f"\t[{datetime.now().strftime('%H:%M:%S')}]Lendo arquivo de teste...")
            path_arquivo_teste = f'{path_folder}/teste-{datahora}.json'
            df_teste = load_df(path_arquivo_teste)

            print(f"\t[{datetime.now().strftime('%H:%M:%S')}]Lendo arquivos de treino...")
            path_arquivo_treino_1 = f'{path_folder}/{(datahora_datetime - timedelta(hours=2)).strftime("%Y-%m-%d_%H")}.json'
            path_arquivo_treino_2 = f'{path_folder}/{(datahora_datetime - timedelta(hours=1)).strftime("%Y-%m-%d_%H")}.json'
            gdf_treino = load_gdf_train((path_arquivo_treino_1, path_arquivo_treino_2))
            gdf_treino = change_dataframe_crs(gdf_treino, ['geometry'], 3857)

            for linha in df_teste['linha'].unique():
            # for linha in ['355']:
                print(f"\t\t[{datetime.now().strftime('%H:%M:%S')}]Calculando predições para linha {linha}...")
                df_test_slice = df_teste[df_teste['linha'] == linha]
                trajectory_df_slice =  trajectories_gdf[(trajectories_gdf['linha'] == linha) & (trajectories_gdf['conjunto_dia'] == conjunto_dia)]
                gdf_treino_slice = gdf_treino[gdf_treino['ordem'].isin(df_test_slice['ordem'].unique())]

                gdf_treino_processed = process_current_train_data(gdf_treino_slice, trajectory_df_slice)
                predictions = predict_position_v2(gdf_treino_processed, df_test_slice, trajectory_df_slice)
                predictions_for_this_datahora.append(predictions)
            
            print(f"[{datetime.now().strftime('%H:%M:%S')}]Predição para {datahora} finalizada.")

            all_predictions_this_data_hora = pd.concat(predictions_for_this_datahora)
            all_predictions_this_data_hora = change_dataframe_crs(all_predictions_this_data_hora, ['geometry_predicted'], crs=4326)
            all_predictions_this_data_hora['latitude_predicted'] = all_predictions_this_data_hora['geometry_predicted'].apply(lambda x: x.y)
            all_predictions_this_data_hora['longitude_predicted'] = all_predictions_this_data_hora['geometry_predicted'].apply(lambda x: x.x)
            all_predictions_this_data_hora['datahora_group'] = datahora
            all_predictions.append(all_predictions_this_data_hora)

            predictions_to_insert = all_predictions_this_data_hora.drop(columns='datahora')
            predictions_to_insert.to_postgis('predictions_made', con=db_engine_alchemy, if_exists='append', index=False)
        except Exception as e:
            traceback.print_exc()
            print(f"Erro ao fazer predições para {datahora}: {str(e)}")


    return pd.concat(all_predictions)

# %%
predictions_to_do = [('2024-05-16_08', 'WEEKDAY'),
                     ('2024-05-16_16', 'WEEKDAY'),
                     ('2024-05-17_07', 'WEEKDAY'),
                     ('2024-05-17_15', 'WEEKDAY'),
                     ('2024-05-18_12', 'SABADO'),
                     ('2024-05-18_20', 'SABADO'),
                     ('2024-05-19_11', 'DOMINGO'),
                     ('2024-05-19_19', 'DOMINGO'),
                     ('2024-05-20_09', 'WEEKDAY'),
                     ('2024-05-20_17', 'WEEKDAY'),]

predictions = execute_all_predictions(predictions_to_do)
# Out:
# [17:28:45]Começando predição para 2024-05-16_08
# 	[17:28:45]Lendo arquivo de teste...
# 	[17:28:47]Lendo arquivos de treino...
# 		[17:29:26]Calculando predições para linha 422...
# 		[17:29:43]Calculando predições para linha 774...
# 		[17:29:51]Calculando predições para linha 634...
# 		[17:30:00]Calculando predições para linha 309...
# 		[17:30:14]Calculando predições para linha 606...
# 		[17:30:21]Calculando predições para linha 355...
# 		[17:30:27]Calculando predições para linha 483...
# 		[17:30:34]Calculando predições para linha 554...
# 		[17:30:50]Calculando predições para linha 399...
# 		[17:30:55]Calculando predições para linha 629...
# 		[17:31:09]Calculando predições para linha 639...
# 		[17:31:24]Calculando predições para linha 371...
# 		[17:31:42]Calculando predições para linha 557...
# 		[17:31:55]Calculando predições para linha 864...
# 		[17:32:07]Calculando predições para linha 324...
# 		[17:32:17]Calculando predições para linha 292...
# 		[17:32:24]Calculando predições para linha 918...
# 		[17:32:32]Calculando predições para linha 343...
# 		[17:32:43]Calculando predições para linha 624...
# 		[17:32:54]Calculando predições para linha 917...
# 		[17:33:03]Calculando predições para linha 565...
# 		[17:33:21]Calculando predições para linha 838...
# 		[17:33:30]Calculando predições para linha 397...
# 		[17:33:37]Calculando predições para linha 638...
# 		[17:33:45]Calculando predições para linha 550...
# 		[17:33:56]Calculando predições para linha 2803...
# 		[17:34:03]Calculando predições para linha 878...
# 		[17:34:17]Calculando predições para linha 553...
# 		[17:34:29]Calculando predições para linha 803...
# 		[17:34:47]Calculando predições para linha 108...
# 		[17:34:52]Calculando predições para linha 457...
# 		[17:35:04]Calculando predições para linha 759...
# 		[17:35:09]Calculando predições para linha 388...
# 		[17:35:15]Calculando predições para linha 100...
# 		[17:35:30]Calculando predições para linha 415...
# 		[17:35:47]Calculando predições para linha 2336...
# 		[17:35:58]Calculando predições para linha 298...
# 		[17:36:07]Calculando predições para linha 867...
# 		[17:36:14]Calculando predições para linha 328...
# 		[17:36:24]Calculando predições para linha 665...
# 		[17:36:35]Calculando predições para linha 315...
# 		[17:36:44]Calculando predições para linha 232...
# 		[17:36:51]Calculando predições para linha 497...
# 		[17:36:59]Calculando predições para linha 756...
# 		[17:37:09]Calculando predições para linha 905...
# 		[17:37:17]Calculando predições para linha 779...
# 		[17:37:22]Calculando predições para linha 3...
# 		[17:37:23]Calculando predições para linha 852...
# [17:37:26]Predição para 2024-05-16_08 finalizada.
# [17:37:35]Começando predição para 2024-05-16_16
# 	[17:37:35]Lendo arquivo de teste...
# 	[17:37:36]Lendo arquivos de treino...
# 		[17:38:25]Calculando predições para linha 457...
# 		[17:38:41]Calculando predições para linha 756...
# 		[17:38:50]Calculando predições para linha 624...
# 		[17:39:02]Calculando predições para linha 422...
# 		[17:39:33]Calculando predições para linha 550...
# 		[17:39:47]Calculando predições para linha 324...
# 		[17:40:00]Calculando predições para linha 838...
# 		[17:40:11]Calculando predições para linha 557...
# 		[17:40:30]Calculando predições para linha 638...
# 		[17:40:43]Calculando predições para linha 629...
# 		[17:40:58]Calculando predições para linha 232...
# 		[17:41:12]Calculando predições para linha 388...
# 		[17:41:19]Calculando predições para linha 665...
# 		[17:41:34]Calculando predições para linha 634...
# 		[17:41:45]Calculando predições para linha 774...
# 		[17:41:55]Calculando predições para linha 415...
# 		[17:42:12]Calculando predições para linha 639...
# 		[17:42:30]Calculando predições para linha 565...
# 		[17:42:49]Calculando predições para linha 399...
# 		[17:42:54]Calculando predições para linha 864...
# 		[17:43:08]Calculando predições para linha 917...
# 		[17:43:18]Calculando predições para linha 553...
# 		[17:43:33]Calculando predições para linha 328...
# 		[17:43:42]Calculando predições para linha 803...
# 		[17:43:53]Calculando predições para linha 100...
# 		[17:44:12]Calculando predições para linha 343...
# 		[17:44:26]Calculando predições para linha 483...
# 		[17:44:42]Calculando predições para linha 355...
# 		[17:44:51]Calculando predições para linha 2336...
# 		[17:44:59]Calculando predições para linha 554...
# 		[17:45:18]Calculando predições para linha 878...
# 		[17:45:31]Calculando predições para linha 108...
# 		[17:45:38]Calculando predições para linha 298...
# 		[17:45:50]Calculando predições para linha 371...
# 		[17:46:11]Calculando predições para linha 315...
# 		[17:46:25]Calculando predições para linha 779...
# 		[17:46:30]Calculando predições para linha 606...
# 		[17:46:43]Calculando predições para linha 905...
# 		[17:46:50]Calculando predições para linha 309...
# 		[17:47:07]Calculando predições para linha 292...
# 		[17:47:15]Calculando predições para linha 918...
# 		[17:47:27]Calculando predições para linha 497...
# 		[17:47:37]Calculando predições para linha 867...
# 		[17:47:44]Calculando predições para linha 759...
# 		[17:47:50]Calculando predições para linha 3...
# 		[17:47:54]Calculando predições para linha 397...
# 		[17:48:00]Calculando predições para linha 852...
# 		[17:48:04]Calculando predições para linha 2803...
# [17:48:13]Predição para 2024-05-16_16 finalizada.
# [17:48:22]Começando predição para 2024-05-17_07
# 	[17:48:22]Lendo arquivo de teste...
# 	[17:48:24]Lendo arquivos de treino...
# 		[17:48:56]Calculando predições para linha 457...
# 		[17:49:05]Calculando predições para linha 624...
# 		[17:49:16]Calculando predições para linha 388...
# 		[17:49:22]Calculando predições para linha 756...
# 		[17:49:32]Calculando predições para linha 878...
# 		[17:49:46]Calculando predições para linha 315...
# 		[17:49:54]Calculando predições para linha 905...
# 		[17:50:00]Calculando predições para linha 422...
# 		[17:50:10]Calculando predições para linha 634...
# 		[17:50:20]Calculando predições para linha 553...
# 		[17:50:31]Calculando predições para linha 2803...
# 		[17:50:36]Calculando predições para linha 298...
# 		[17:50:43]Calculando predições para linha 550...
# 		[17:50:50]Calculando predições para linha 324...
# 		[17:50:59]Calculando predições para linha 554...
# 		[17:51:14]Calculando predições para linha 108...
# 		[17:51:18]Calculando predições para linha 779...
# 		[17:51:22]Calculando predições para linha 665...
# 		[17:51:32]Calculando predições para linha 867...
# 		[17:51:38]Calculando predições para linha 415...
# 		[17:51:53]Calculando predições para linha 803...
# 		[17:52:05]Calculando predições para linha 864...
# 		[17:52:13]Calculando predições para linha 629...
# 		[17:52:26]Calculando predições para linha 917...
# 		[17:52:34]Calculando predições para linha 918...
# 		[17:52:41]Calculando predições para linha 232...
# 		[17:52:45]Calculando predições para linha 309...
# 		[17:52:56]Calculando predições para linha 100...
# 		[17:53:06]Calculando predições para linha 557...
# 		[17:53:13]Calculando predições para linha 3...
# 		[17:53:18]Calculando predições para linha 565...
# 		[17:53:30]Calculando predições para linha 639...
# 		[17:53:45]Calculando predições para linha 2336...
# 		[17:53:55]Calculando predições para linha 343...
# 		[17:54:02]Calculando predições para linha 328...
# 		[17:54:10]Calculando predições para linha 355...
# 		[17:54:16]Calculando predições para linha 638...
# 		[17:54:21]Calculando predições para linha 606...
# 		[17:54:26]Calculando predições para linha 399...
# 		[17:54:29]Calculando predições para linha 759...
# 		[17:54:33]Calculando predições para linha 838...
# 		[17:54:40]Calculando predições para linha 497...
# 		[17:54:46]Calculando predições para linha 774...
# 		[17:54:53]Calculando predições para linha 371...
# 		[17:55:08]Calculando predições para linha 292...
# 		[17:55:13]Calculando predições para linha 483...
# 		[17:55:20]Calculando predições para linha 397...
# 		[17:55:28]Calculando predições para linha 852...
# [17:55:30]Predição para 2024-05-17_07 finalizada.
# [17:55:38]Começando predição para 2024-05-17_15
# 	[17:55:38]Lendo arquivo de teste...
# 	[17:55:40]Lendo arquivos de treino...
# 		[17:56:26]Calculando predições para linha 638...
# 		[17:56:40]Calculando predições para linha 483...
# 		[17:56:58]Calculando predições para linha 606...
# 		[17:57:11]Calculando predições para linha 497...
# 		[17:57:24]Calculando predições para linha 298...
# 		[17:57:36]Calculando predições para linha 315...
# 		[17:57:49]Calculando predições para linha 550...
# 		[17:58:10]Calculando predições para linha 422...
# 		[17:58:45]Calculando predições para linha 371...
# 		[17:59:06]Calculando predições para linha 343...
# 		[17:59:19]Calculando predições para linha 878...
# 		[17:59:35]Calculando predições para linha 328...
# 		[17:59:43]Calculando predições para linha 557...
# 		[18:00:04]Calculando predições para linha 324...
# 		[18:00:19]Calculando predições para linha 292...
# 		[18:00:27]Calculando predições para linha 774...
# 		[18:00:36]Calculando predições para linha 108...
# 		[18:00:43]Calculando predições para linha 355...
# 		[18:00:52]Calculando predições para linha 918...
# 		[18:01:05]Calculando predições para linha 629...
# 		[18:01:22]Calculando predições para linha 415...
# 		[18:01:39]Calculando predições para linha 554...
# 		[18:01:57]Calculando predições para linha 553...
# 		[18:02:12]Calculando predições para linha 756...
# 		[18:02:21]Calculando predições para linha 457...
# 		[18:02:37]Calculando predições para linha 864...
# 		[18:02:53]Calculando predições para linha 565...
# 		[18:03:14]Calculando predições para linha 388...
# 		[18:03:25]Calculando predições para linha 639...
# 		[18:03:46]Calculando predições para linha 905...
# 		[18:03:54]Calculando predições para linha 100...
# 		[18:04:13]Calculando predições para linha 624...
# 		[18:04:25]Calculando predições para linha 2803...
# 		[18:04:35]Calculando predições para linha 309...
# 		[18:04:55]Calculando predições para linha 917...
# 		[18:05:06]Calculando predições para linha 634...
# 		[18:05:16]Calculando predições para linha 803...
# 		[18:05:29]Calculando predições para linha 838...
# 		[18:05:39]Calculando predições para linha 397...
# 		[18:05:46]Calculando predições para linha 779...
# 		[18:05:51]Calculando predições para linha 867...
# 		[18:05:58]Calculando predições para linha 232...
# 		[18:06:13]Calculando predições para linha 665...
# 		[18:06:29]Calculando predições para linha 852...
# 		[18:06:33]Calculando predições para linha 2336...
# 		[18:06:42]Calculando predições para linha 3...
# 		[18:06:45]Calculando predições para linha 759...
# 		[18:06:51]Calculando predições para linha 399...
# [18:06:56]Predição para 2024-05-17_15 finalizada.
# [18:07:06]Começando predição para 2024-05-18_12
# 	[18:07:06]Lendo arquivo de teste...
# 	[18:07:07]Lendo arquivos de treino...
# 		[18:07:43]Calculando predições para linha 483...
# 		[18:07:57]Calculando predições para linha 917...
# 		[18:08:04]Calculando predições para linha 557...
# 		[18:08:23]Calculando predições para linha 774...
# 		[18:08:30]Calculando predições para linha 232...
# 		[18:08:40]Calculando predições para linha 554...
# 		[18:08:49]Calculando predições para linha 2336...
# 		[18:09:00]Calculando predições para linha 422...
# 		[18:09:15]Calculando predições para linha 864...
# 		[18:09:30]Calculando predições para linha 355...
# 		[18:09:40]Calculando predições para linha 565...
# 		[18:09:51]Calculando predições para linha 328...
# 		[18:09:58]Calculando predições para linha 415...
# 		[18:10:12]Calculando predições para linha 343...
# 		[18:10:24]Calculando predições para linha 315...
# 		[18:10:37]Calculando predições para linha 639...
# 		[18:10:53]Calculando predições para linha 803...
# 		[18:11:02]Calculando predições para linha 371...
# 		[18:11:18]Calculando predições para linha 779...
# 		[18:11:22]Calculando predições para linha 553...
# 		[18:11:31]Calculando predições para linha 550...
# 		[18:11:46]Calculando predições para linha 606...
# 		[18:11:57]Calculando predições para linha 388...
# 		[18:12:08]Calculando predições para linha 497...
# 		[18:12:20]Calculando predições para linha 309...
# 		[18:12:26]Calculando predições para linha 324...
# 		[18:12:35]Calculando predições para linha 2803...
# 		[18:12:41]Calculando predições para linha 100...
# 		[18:12:53]Calculando predições para linha 399...
# 		[18:12:58]Calculando predições para linha 108...
# 		[18:13:03]Calculando predições para linha 918...
# 		[18:13:11]Calculando predições para linha 292...
# 		[18:13:15]Calculando predições para linha 878...
# 		[18:13:29]Calculando predições para linha 852...
# 		[18:13:32]Calculando predições para linha 665...
# 		[18:13:43]Calculando predições para linha 638...
# 		[18:13:51]Calculando predições para linha 867...
# 		[18:13:58]Calculando predições para linha 838...
# 		[18:14:07]Calculando predições para linha 634...
# 		[18:14:13]Calculando predições para linha 629...
# 		[18:14:25]Calculando predições para linha 759...
# 		[18:14:30]Calculando predições para linha 3...
# 		[18:14:33]Calculando predições para linha 756...
# 		[18:14:40]Calculando predições para linha 397...
# 		[18:14:48]Calculando predições para linha 298...
# 		[18:14:57]Calculando predições para linha 624...
# 		[18:15:06]Calculando predições para linha 905...
# 		[18:15:11]Calculando predições para linha 457...
# [18:15:23]Predição para 2024-05-18_12 finalizada.
# [18:15:30]Começando predição para 2024-05-18_20
# 	[18:15:30]Lendo arquivo de teste...
# 	[18:15:31]Lendo arquivos de treino...
# 		[18:16:00]Calculando predições para linha 665...
# 		[18:16:09]Calculando predições para linha 838...
# 		[18:16:18]Calculando predições para linha 422...
# 		[18:16:33]Calculando predições para linha 343...
# 		[18:16:44]Calculando predições para linha 324...
# 		[18:16:51]Calculando predições para linha 639...
# 		[18:17:06]Calculando predições para linha 629...
# 		[18:17:18]Calculando predições para linha 298...
# 		[18:17:22]Calculando predições para linha 867...
# 		[18:17:28]Calculando predições para linha 371...
# 		[18:17:36]Calculando predições para linha 550...
# 		[18:17:53]Calculando predições para linha 232...
# 		[18:18:01]Calculando predições para linha 803...
# 		[18:18:09]Calculando predições para linha 397...
# 		[18:18:16]Calculando predições para linha 905...
# 		[18:18:21]Calculando predições para linha 918...
# 		[18:18:29]Calculando predições para linha 638...
# 		[18:18:36]Calculando predições para linha 497...
# 		[18:18:44]Calculando predições para linha 315...
# 		[18:18:56]Calculando predições para linha 554...
# 		[18:19:03]Calculando predições para linha 774...
# 		[18:19:10]Calculando predições para linha 108...
# 		[18:19:12]Calculando predições para linha 292...
# 		[18:19:17]Calculando predições para linha 399...
# 		[18:19:22]Calculando predições para linha 100...
# 		[18:19:33]Calculando predições para linha 483...
# 		[18:19:42]Calculando predições para linha 634...
# 		[18:19:48]Calculando predições para linha 3...
# 		[18:19:53]Calculando predições para linha 756...
# 		[18:20:00]Calculando predições para linha 557...
# 		[18:20:15]Calculando predições para linha 864...
# 		[18:20:27]Calculando predições para linha 2803...
# 		[18:20:33]Calculando predições para linha 565...
# 		[18:20:43]Calculando predições para linha 388...
# 		[18:20:52]Calculando predições para linha 852...
# 		[18:20:55]Calculando predições para linha 457...
# 		[18:21:06]Calculando predições para linha 328...
# 		[18:21:10]Calculando predições para linha 309...
# 		[18:21:19]Calculando predições para linha 878...
# 		[18:21:32]Calculando predições para linha 355...
# 		[18:21:37]Calculando predições para linha 759...
# 		[18:21:40]Calculando predições para linha 917...
# 		[18:21:45]Calculando predições para linha 606...
# 		[18:21:53]Calculando predições para linha 553...
# 		[18:22:02]Calculando predições para linha 2336...
# 		[18:22:09]Calculando predições para linha 624...
# 		[18:22:18]Calculando predições para linha 415...
# 		[18:22:30]Calculando predições para linha 779...
# [18:22:32]Predição para 2024-05-18_20 finalizada.
# [18:22:39]Começando predição para 2024-05-19_11
# 	[18:22:39]Lendo arquivo de teste...
# 	[18:22:40]Lendo arquivos de treino...
# 		[18:23:02]Calculando predições para linha 624...
# 		[18:23:07]Calculando predições para linha 399...
# 		[18:23:11]Calculando predições para linha 422...
# 		[18:23:20]Calculando predições para linha 565...
# 		[18:23:28]Calculando predições para linha 553...
# 		[18:23:36]Calculando predições para linha 328...
# 		[18:23:42]Calculando predições para linha 756...
# 		[18:23:47]Calculando predições para linha 457...
# 		[18:23:56]Calculando predições para linha 838...
# 		[18:24:02]Calculando predições para linha 483...
# 		[18:24:12]Calculando predições para linha 606...
# 		[18:24:19]Calculando predições para linha 108...
# 		[18:24:23]Calculando predições para linha 371...
# 		[18:24:29]Calculando predições para linha 397...
# 		[18:24:42]Calculando predições para linha 864...
# 		[18:24:52]Calculando predições para linha 324...
# 		[18:24:59]Calculando predições para linha 2803...
# 		[18:25:03]Calculando predições para linha 550...
# 		[18:25:13]Calculando predições para linha 309...
# 		[18:25:20]Calculando predições para linha 629...
# 		[18:25:29]Calculando predições para linha 665...
# 		[18:25:35]Calculando predições para linha 415...
# 		[18:25:42]Calculando predições para linha 878...
# 		[18:25:53]Calculando predições para linha 554...
# 		[18:25:59]Calculando predições para linha 315...
# 		[18:26:08]Calculando predições para linha 388...
# 		[18:26:15]Calculando predições para linha 779...
# 		[18:26:17]Calculando predições para linha 634...
# 		[18:26:20]Calculando predições para linha 343...
# 		[18:26:28]Calculando predições para linha 232...
# 		[18:26:32]Calculando predições para linha 759...
# 		[18:26:35]Calculando predições para linha 918...
# 		[18:26:41]Calculando predições para linha 292...
# 		[18:26:44]Calculando predições para linha 2336...
# 		[18:26:51]Calculando predições para linha 298...
# 		[18:26:54]Calculando predições para linha 639...
# 		[18:27:04]Calculando predições para linha 557...
# 		[18:27:13]Calculando predições para linha 638...
# 		[18:27:18]Calculando predições para linha 803...
# 		[18:27:24]Calculando predições para linha 100...
# 		[18:27:33]Calculando predições para linha 867...
# 		[18:27:39]Calculando predições para linha 774...
# 		[18:27:44]Calculando predições para linha 852...
# 		[18:27:47]Calculando predições para linha 3...
# 		[18:27:49]Calculando predições para linha 905...
# 		[18:27:52]Calculando predições para linha 497...
# 		[18:27:57]Calculando predições para linha 355...
# 		[18:28:03]Calculando predições para linha 917...
# [18:28:06]Predição para 2024-05-19_11 finalizada.
# [18:28:11]Começando predição para 2024-05-19_19
# 	[18:28:11]Lendo arquivo de teste...
# 	[18:28:11]Lendo arquivos de treino...
# 		[18:28:32]Calculando predições para linha 550...
# 		[18:28:42]Calculando predições para linha 315...
# 		[18:28:48]Calculando predições para linha 554...
# 		[18:28:53]Calculando predições para linha 2336...
# 		[18:29:00]Calculando predições para linha 497...
# 		[18:29:05]Calculando predições para linha 864...
# 		[18:29:15]Calculando predições para linha 629...
# 		[18:29:22]Calculando predições para linha 553...
# 		[18:29:31]Calculando predições para linha 422...
# 		[18:29:39]Calculando predições para linha 803...
# 		[18:29:44]Calculando predições para linha 557...
# 		[18:29:53]Calculando predições para linha 756...
# 		[18:29:58]Calculando predições para linha 100...
# 		[18:30:07]Calculando predições para linha 565...
# 		[18:30:18]Calculando predições para linha 867...
# 		[18:30:24]Calculando predições para linha 917...
# 		[18:30:27]Calculando predições para linha 298...
# 		[18:30:31]Calculando predições para linha 905...
# 		[18:30:34]Calculando predições para linha 483...
# 		[18:30:46]Calculando predições para linha 324...
# 		[18:30:52]Calculando predições para linha 918...
# 		[18:30:57]Calculando predições para linha 774...
# 		[18:31:01]Calculando predições para linha 606...
# 		[18:31:09]Calculando predições para linha 108...
# 		[18:31:11]Calculando predições para linha 638...
# 		[18:31:16]Calculando predições para linha 665...
# 		[18:31:22]Calculando predições para linha 309...
# 		[18:31:29]Calculando predições para linha 639...
# 		[18:31:37]Calculando predições para linha 878...
# 		[18:31:50]Calculando predições para linha 355...
# 		[18:31:55]Calculando predições para linha 397...
# 		[18:32:04]Calculando predições para linha 838...
# 		[18:32:10]Calculando predições para linha 634...
# 		[18:32:13]Calculando predições para linha 292...
# 		[18:32:16]Calculando predições para linha 457...
# 		[18:32:25]Calculando predições para linha 388...
# 		[18:32:31]Calculando predições para linha 343...
# 		[18:32:39]Calculando predições para linha 371...
# 		[18:32:45]Calculando predições para linha 759...
# 		[18:32:49]Calculando predições para linha 624...
# 		[18:32:54]Calculando predições para linha 852...
# 		[18:32:56]Calculando predições para linha 232...
# 		[18:33:01]Calculando predições para linha 2803...
# 		[18:33:05]Calculando predições para linha 415...
# 		[18:33:12]Calculando predições para linha 328...
# 		[18:33:17]Calculando predições para linha 399...
# 		[18:33:20]Calculando predições para linha 779...
# 		[18:33:21]Calculando predições para linha 3...
# [18:33:26]Predição para 2024-05-19_19 finalizada.
# [18:33:30]Começando predição para 2024-05-20_09
# 	[18:33:30]Lendo arquivo de teste...
# 	[18:33:32]Lendo arquivos de treino...
# 		[18:34:19]Calculando predições para linha 2336...
# 		[18:34:29]Calculando predições para linha 553...
# 		[18:34:43]Calculando predições para linha 864...
# 		[18:34:56]Calculando predições para linha 639...
# 		[18:35:10]Calculando predições para linha 388...
# 		[18:35:17]Calculando predições para linha 634...
# 		[18:35:28]Calculando predições para linha 292...
# 		[18:35:36]Calculando predições para linha 399...
# 		[18:35:42]Calculando predições para linha 838...
# 		[18:35:52]Calculando predições para linha 905...
# 		[18:36:00]Calculando predições para linha 422...
# 		[18:36:25]Calculando predições para linha 918...
# 		[18:36:36]Calculando predições para linha 550...
# 		[18:36:53]Calculando predições para linha 565...
# 		[18:37:15]Calculando predições para linha 629...
# 		[18:37:29]Calculando predições para linha 867...
# 		[18:37:37]Calculando predições para linha 108...
# 		[18:37:42]Calculando predições para linha 554...
# 		[18:37:58]Calculando predições para linha 232...
# 		[18:38:08]Calculando predições para linha 343...
# 		[18:38:19]Calculando predições para linha 309...
# 		[18:38:35]Calculando predições para linha 100...
# 		[18:38:53]Calculando predições para linha 457...
# 		[18:39:07]Calculando predições para linha 665...
# 		[18:39:20]Calculando predições para linha 624...
# 		[18:39:32]Calculando predições para linha 606...
# 		[18:39:40]Calculando predições para linha 397...
# 		[18:39:48]Calculando predições para linha 638...
# 		[18:39:59]Calculando predições para linha 371...
# 		[18:40:17]Calculando predições para linha 774...
# 		[18:40:25]Calculando predições para linha 355...
# 		[18:40:32]Calculando predições para linha 483...
# 		[18:40:42]Calculando predições para linha 328...
# 		[18:40:50]Calculando predições para linha 497...
# 		[18:40:58]Calculando predições para linha 315...
# 		[18:41:08]Calculando predições para linha 298...
# 		[18:41:18]Calculando predições para linha 557...
# 		[18:41:35]Calculando predições para linha 756...
# 		[18:41:45]Calculando predições para linha 324...
# 		[18:41:57]Calculando predições para linha 759...
# 		[18:42:02]Calculando predições para linha 878...
# 		[18:42:17]Calculando predições para linha 803...
# 		[18:42:31]Calculando predições para linha 779...
# 		[18:42:35]Calculando predições para linha 415...
# 		[18:42:51]Calculando predições para linha 2803...
# 		[18:42:59]Calculando predições para linha 852...
# 		[18:43:02]Calculando predições para linha 917...
# 		[18:43:12]Calculando predições para linha 3...
# [18:43:14]Predição para 2024-05-20_09 finalizada.
# [18:43:23]Começando predição para 2024-05-20_17
# 	[18:43:23]Lendo arquivo de teste...
# 	[18:43:25]Lendo arquivos de treino...
# 		[18:44:07]Calculando predições para linha 878...
# 		[18:44:21]Calculando predições para linha 629...
# 		[18:44:33]Calculando predições para linha 557...
# 		[18:44:49]Calculando predições para linha 324...
# 		[18:45:00]Calculando predições para linha 422...
# 		[18:45:30]Calculando predições para linha 550...
# 		[18:45:44]Calculando predições para linha 397...
# 		[18:45:50]Calculando predições para linha 634...
# 		[18:46:01]Calculando predições para linha 100...
# 		[18:46:18]Calculando predições para linha 457...
# 		[18:46:35]Calculando predições para linha 864...
# 		[18:46:47]Calculando predições para linha 309...
# 		[18:47:05]Calculando predições para linha 315...
# 		[18:47:19]Calculando predições para linha 639...
# 		[18:47:34]Calculando predições para linha 3...
# 		[18:47:38]Calculando predições para linha 343...
# 		[18:47:51]Calculando predições para linha 232...
# 		[18:48:04]Calculando predições para linha 371...
# 		[18:48:23]Calculando predições para linha 638...
# 		[18:48:35]Calculando predições para linha 497...
# 		[18:48:46]Calculando predições para linha 867...
# 		[18:48:53]Calculando predições para linha 606...
# 		[18:49:05]Calculando predições para linha 565...
# 		[18:49:21]Calculando predições para linha 355...
# 		[18:49:29]Calculando predições para linha 803...
# 		[18:49:37]Calculando predições para linha 624...
# 		[18:49:49]Calculando predições para linha 415...
# 		[18:50:04]Calculando predições para linha 483...
# 		[18:50:17]Calculando predições para linha 852...
# 		[18:50:21]Calculando predições para linha 553...
# 		[18:50:34]Calculando predições para linha 838...
# 		[18:50:43]Calculando predições para linha 399...
# 		[18:50:50]Calculando predições para linha 2336...
# 		[18:50:58]Calculando predições para linha 917...
# 		[18:51:09]Calculando predições para linha 756...
# 		[18:51:18]Calculando predições para linha 298...
# 		[18:51:29]Calculando predições para linha 328...
# 		[18:51:38]Calculando predições para linha 905...
# 		[18:51:46]Calculando predições para linha 108...
# 		[18:51:52]Calculando predições para linha 918...
# 		[18:52:02]Calculando predições para linha 774...
# 		[18:52:09]Calculando predições para linha 779...
# 		[18:52:14]Calculando predições para linha 665...
# 		[18:52:28]Calculando predições para linha 554...
# 		[18:52:45]Calculando predições para linha 292...
# 		[18:52:55]Calculando predições para linha 388...
# 		[18:53:03]Calculando predições para linha 2803...
# 		[18:53:13]Calculando predições para linha 759...
# [18:53:17]Predição para 2024-05-20_17 finalizada.
